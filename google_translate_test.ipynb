# %%
from google.cloud import translate_v2 as translate
import requests
from bs4 import BeautifulSoup
from collections import Counter
import re
import pandas as pd
import os
from function_words import unique_function_words
# Out:
# 181 164

# %%
print(os.getenv('GOOGLE_APPLICATION_CREDENTIALS'))
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = "/Users/roneng100/API Keys/website-translation-419023-4572f2415643.json"
# Out:
# /Users/roneng100/API Keys/website-translation-419023-4572f2415643.json

# %%
def translate_text(text="Hello, world!", target_language="es"):

    translate_client = translate.Client()
    
    if isinstance(target_language, str):
        target_language = target_language.lower()
    
    result = translate_client.translate(text, target_language=target_language)
    
    print(u"Text: {}".format(result['input']))
    print(u"Translation: {}".format(result['translatedText']))
    print(u"Detected source language: {}".format(result['detectedSourceLanguage']))

    return result['translatedText']

if __name__ == "__main__":
    translate_text("Hello, world!", "es")
# Out:
# Text: Hello, world!
# Translation: ¡Hola Mundo!
# Detected source language: en

# %%
def extract_words_from_txt(file_path):
    # Try opening the file with different encoding if UTF-8 doesn't work
    try:
        # Try opening the file with the default UTF-8 encoding
        with open(file_path, 'r', encoding='utf-8') as file:
            text = file.read()
    except UnicodeDecodeError:
        # If UTF-8 doesn't work, try with 'ISO-8859-1'
        with open(file_path, 'r', encoding='ISO-8859-1') as file:
            text = file.read()
    except Exception as e:
        # If other errors occur, raise them
        raise e
    
    # Split the text by whitespace to get the words
    words = text.split()
    
    return words

file_path = 'Subject_Terms.txt'
words = extract_words_from_txt(file_path)
print(len(words), words)

def normalize_words(word_list):
    # Use regular expression to remove any non-alphabetical characters (keeping only a-z and A-Z)
    normalized_words = [re.sub(r'[^a-zA-Z]', '', word) for word in word_list]
    # Remove any empty strings that may result from normalization
    normalized_words = [word for word in normalized_words if word]
    return normalized_words

# Example usage
test_words = ['(subject', 'fi?n@l', 'draft)', 'Agricul-tural', 'r3search', 'C0mmittee']
normalize_word = normalize_words(words)
print(len(normalize_word), normalize_word)
unique_words = set(normalize_word)
print(len(unique_words), unique_words)
# Out:
# 1767 ['SUBJECT', 'TERMS:', 'FINAL', 'COMMITTEE', 'DRAFT', 'Agriculture', 'and', 'Food', 'Agricultural', 'marketing', 'Agricultural', 'practices', 'Agricultural', 'research', 'Agricultural', 'subsidies', 'Alcoholic', 'beverages', 'Aquaculture', 'Farmland', 'Food', 'assistance', 'Food', 'industry', 'Food', 'labeling', 'Food', 'safety', 'Genetically', 'modified', 'organisms', '(G.M.O.)', 'Livestock', 'Animals', 'Animal', 'diseases', 'Animal', 'protection', 'Service', 'animals', 'Veterinary', 'medicine', 'Wildlife', '{scope', 'note:', 'includes', 'tracking,', 'trafficking,', 'poaching,', 'and', 'refuges}', 'Arts', 'and', 'Culture', '{scope', 'note:', 'See', '�Intellectual', 'Property�', 'for', 'copyright-related', 'matters.}', 'Archives', 'Attire', 'Cultural', 'heritage', 'Libraries', 'Museums', 'Religious', 'buildings', 'Statues', 'and', 'monuments', 'Television', 'and', 'film', 'Commerce', '{scope', 'note:', 'Includes', 'e-commerce;', 'See', 'also', '�Foreign', 'Trade', 'and', 'International', 'Finance.�}', 'Building', 'construction', 'Business', 'ethics', 'Business', 'investment', 'and', 'capital', 'Competition,', 'antitrust,', 'and', 'monopolies', 'Consumer', 'protection', 'Cryptocurrency', '{scope', 'note:', 'includes', 'all', 'forms', 'of', 'cybercurrency', 'such', 'as', 'Bitcoin}', 'Industrial', 'facilities', 'Manufacturing', 'Marketing', 'and', 'advertising', 'Minority', 'and', 'disadvantaged', 'businesses', 'Product', 'development', 'and', 'innovation', 'Real', 'estate', 'Small', 'business', 'oxim', 'Women', 'in', 'business', 'Communications', '{scope', 'note:', 'includes', 'telecommunications}', 'Broadcasting', 'Cell', 'phones', 'Internet', 'News', 'media', 'and', 'reporting', 'Social', 'media', 'Television', 'and', 'Film', 'Corporations', 'and', 'Associations', 'Limited', 'liability', 'companies', '(L.L.C.)', 'Nongovernmental', 'organizations', '(N.G.O.)', 'Nonprofit', 'corporations', 'Partnerships', 'Crime', 'and', 'Law', 'Enforcement', '{scope', 'note:', 'Refers', 'to', 'domestic', 'laws;', 'use', '�International', 'Affairs�', 'for', 'international', 'crime', 'terms.}', 'Assault', 'and', 'battery', 'Blasphemy', 'Bribery', 'Capital', 'punishment', 'Conspiracy', 'Controlled', 'substances', 'Correctional', 'facilities', 'and', 'imprisonment', 'Corruption', 'Crime', 'prevention', 'Crime', 'victims', 'Crimes', 'against', 'children', 'Crimes', 'against', 'property', 'Crimes', 'against', 'the', 'state', 'Crimes', 'against', 'women', 'Criminal', 'procedure', 'Cybercrime', 'Domestic', 'violence', 'Driving', 'while', 'intoxicated', 'Drug', 'trafficking', 'Electronic', 'surveillance', 'Espionage', 'Extradition', 'Foreign', 'judgments', 'Forfeiture', 'Fraud', 'and', 'financial', 'crimes', 'Harassment', 'Hate', 'crimes', 'Homicide', 'Human', 'trafficking', 'Juries', 'Juvenile', 'crime', 'Law', 'enforcement', 'officers', 'Maintenance', 'of', 'public', 'order', 'Money', 'laundering', 'Organized', 'crime', 'and', 'gangs', 'Perjury', 'Piracy', 'Probation', 'and', 'parole', 'Sentencing', 'Sex', 'offenses', 'Slavery', '{scope', 'note:', 'Includes', 'indentured', 'servitude}', 'Smuggling', 'Statute', 'of', 'limitations', 'Terrorism', 'Torture', 'Weapons', '{scope', 'note:', 'Includes', 'weapons', 'development,', 'chemical', 'and', 'biological', 'weapons,', 'nuclear', 'weapons,', 'ammunitions,', 'firearms', 'and', 'explosives}', 'White-collar', 'crime', 'Witness', 'protection', 'Economics', 'and', 'Public', 'Finance', 'Appropriations', 'Budget', 'Economic', 'development', 'Government', 'lending', 'and', 'loan', 'guarantees', 'Government', 'trust', 'funds', 'Inflation', 'and', 'prices', 'Monetary', 'policy', 'State', 'and', 'local', 'finance', 'Education', 'Adult', 'education', 'and', 'literacy', 'Charter', 'schools', 'Compulsory', 'education', 'Education', 'funding', 'Elementary', 'and', 'secondary', 'education', 'Foreign', 'language', 'and', 'bilingual', 'programs', 'Gifted', 'and', 'talented', 'programs', 'Higher', 'education', 'Prescho ...
# 1766 ['SUBJECT', 'TERMS', 'FINAL', 'COMMITTEE', 'DRAFT', 'Agriculture', 'and', 'Food', 'Agricultural', 'marketing', 'Agricultural', 'practices', 'Agricultural', 'research', 'Agricultural', 'subsidies', 'Alcoholic', 'beverages', 'Aquaculture', 'Farmland', 'Food', 'assistance', 'Food', 'industry', 'Food', 'labeling', 'Food', 'safety', 'Genetically', 'modified', 'organisms', 'GMO', 'Livestock', 'Animals', 'Animal', 'diseases', 'Animal', 'protection', 'Service', 'animals', 'Veterinary', 'medicine', 'Wildlife', 'scope', 'note', 'includes', 'tracking', 'trafficking', 'poaching', 'and', 'refuges', 'Arts', 'and', 'Culture', 'scope', 'note', 'See', 'Intellectual', 'Property', 'for', 'copyrightrelated', 'matters', 'Archives', 'Attire', 'Cultural', 'heritage', 'Libraries', 'Museums', 'Religious', 'buildings', 'Statues', 'and', 'monuments', 'Television', 'and', 'film', 'Commerce', 'scope', 'note', 'Includes', 'ecommerce', 'See', 'also', 'Foreign', 'Trade', 'and', 'International', 'Finance', 'Building', 'construction', 'Business', 'ethics', 'Business', 'investment', 'and', 'capital', 'Competition', 'antitrust', 'and', 'monopolies', 'Consumer', 'protection', 'Cryptocurrency', 'scope', 'note', 'includes', 'all', 'forms', 'of', 'cybercurrency', 'such', 'as', 'Bitcoin', 'Industrial', 'facilities', 'Manufacturing', 'Marketing', 'and', 'advertising', 'Minority', 'and', 'disadvantaged', 'businesses', 'Product', 'development', 'and', 'innovation', 'Real', 'estate', 'Small', 'business', 'oxim', 'Women', 'in', 'business', 'Communications', 'scope', 'note', 'includes', 'telecommunications', 'Broadcasting', 'Cell', 'phones', 'Internet', 'News', 'media', 'and', 'reporting', 'Social', 'media', 'Television', 'and', 'Film', 'Corporations', 'and', 'Associations', 'Limited', 'liability', 'companies', 'LLC', 'Nongovernmental', 'organizations', 'NGO', 'Nonprofit', 'corporations', 'Partnerships', 'Crime', 'and', 'Law', 'Enforcement', 'scope', 'note', 'Refers', 'to', 'domestic', 'laws', 'use', 'International', 'Affairs', 'for', 'international', 'crime', 'terms', 'Assault', 'and', 'battery', 'Blasphemy', 'Bribery', 'Capital', 'punishment', 'Conspiracy', 'Controlled', 'substances', 'Correctional', 'facilities', 'and', 'imprisonment', 'Corruption', 'Crime', 'prevention', 'Crime', 'victims', 'Crimes', 'against', 'children', 'Crimes', 'against', 'property', 'Crimes', 'against', 'the', 'state', 'Crimes', 'against', 'women', 'Criminal', 'procedure', 'Cybercrime', 'Domestic', 'violence', 'Driving', 'while', 'intoxicated', 'Drug', 'trafficking', 'Electronic', 'surveillance', 'Espionage', 'Extradition', 'Foreign', 'judgments', 'Forfeiture', 'Fraud', 'and', 'financial', 'crimes', 'Harassment', 'Hate', 'crimes', 'Homicide', 'Human', 'trafficking', 'Juries', 'Juvenile', 'crime', 'Law', 'enforcement', 'officers', 'Maintenance', 'of', 'public', 'order', 'Money', 'laundering', 'Organized', 'crime', 'and', 'gangs', 'Perjury', 'Piracy', 'Probation', 'and', 'parole', 'Sentencing', 'Sex', 'offenses', 'Slavery', 'scope', 'note', 'Includes', 'indentured', 'servitude', 'Smuggling', 'Statute', 'of', 'limitations', 'Terrorism', 'Torture', 'Weapons', 'scope', 'note', 'Includes', 'weapons', 'development', 'chemical', 'and', 'biological', 'weapons', 'nuclear', 'weapons', 'ammunitions', 'firearms', 'and', 'explosives', 'Whitecollar', 'crime', 'Witness', 'protection', 'Economics', 'and', 'Public', 'Finance', 'Appropriations', 'Budget', 'Economic', 'development', 'Government', 'lending', 'and', 'loan', 'guarantees', 'Government', 'trust', 'funds', 'Inflation', 'and', 'prices', 'Monetary', 'policy', 'State', 'and', 'local', 'finance', 'Education', 'Adult', 'education', 'and', 'literacy', 'Charter', 'schools', 'Compulsory', 'education', 'Education', 'funding', 'Elementary', 'and', 'secondary', 'education', 'Foreign', 'language', 'and', 'bilingual', 'programs', 'Gifted', 'and', 'talented', 'programs', 'Higher', 'education', 'Preschool', 'education', 'Private', 'schools', 'School', 'administrati ...
# 907 {'Infectious', 'passenger', 'service', 'Terrorism', 'Double', 'Gifted', 'Sector', 'parttime', 'Forfeiture', 'Income', 'Strategic', 'diet', 'fishing', 'commercial', 'Bridges', 'parks', 'Armed', 'products', 'review', 'industry', 'identify', 'guarantees', 'Labormanagement', 'Use', 'Maps', 'Childrens', 'stabilization', 'community', 'Recreation', 'Bicycling', 'jurisdictions', 'Floods', 'animals', 'Maintenance', 'loan', 'conditions', 'investment', 'Minority', 'Power', 'Libraries', 'prevention', 'Term', 'Refugees', 'News', 'Patients', 'Terminal', 'Juries', 'Territories', 'Trials', 'Nuclear', 'Weather', 'Guard', 'vehicles', 'organisms', 'Service', 'inheritance', 'Inheritance', 'Gambling', 'Blasphemy', 'crimes', 'Epidemics', 'participation', 'income', 'parties', 'cybercurrency', 'Disasters', 'Resources', 'DRAFT', 'biotechnology', 'information', 'restrictions', 'registers', 'Research', 'laws', 'Erosion', 'Animal', 'charitable', 'poaching', 'capital', 'Witnesses', 'buses', 'transmitted', 'Employment', 'immigrants', 'emergency', 'on', 'Segways', 'Charter', 'nuclear', 'documents', 'Environmental', 'cards', 'Rights', 'Taxation', 'Immigration', 'outpatient', 'Examples', 'Investment', 'boats', 'communications', 'groups', 'paramilitary', 'Corporations', 'Housing', 'Migrant', 'as', 'disobedience', 'Monetary', 'schools', 'Sentencing', 'Bankruptcy', 'treaty', 'conservation', 'Army', 'Tobacco', 'treaties', 'Crime', 'mitigation', 'GMO', 'Licensing', 'reform', 'terms', 'timber', 'relations', 'Roads', 'should', 'Genetically', 'property', 'Weapons', 'birth', 'the', 'consular', 'advertising', 'Credit', 'crises', 'Familybased', 'venue', 'debt', 'for', 'Force', 'planning', 'Securities', 'security', 'Navigation', 'Probation', 'institutions', 'Coast', 'US', 'media', 'navigation', 'resources', 'Hazardous', 'training', 'storm', 'Arts', 'Refers', 'areas', 'Pregnancy', 'Detention', 'Pornography', 'transgender', 'servitude', 'Hague', 'used', 'NATO', 'retirement', 'Small', 'costs', 'regulatory', 'Hunting', 'HIPAA', 'Desertification', 'Commerce', 'safety', 'Fraud', 'Budget', 'applied', 'Assault', 'Child', 'antitrust', 'Energy', 'Native', 'Customs', 'consent', 'custody', 'Transportation', 'pensions', 'modified', 'Soil', 'monuments', 'Foreign', 'defects', 'Infrastructure', 'Enforcement', 'speech', 'Plants', 'tax', 'pollution', 'Money', 'state', 'individuals', 'Technical', 'issues', 'Conservation', 'Archives', 'Disaster', 'contracts', 'political', 'health', 'insurance', 'lending', 'Cybersecurity', 'lesbian', 'utility', 'Census', 'assembly', 'Trademarks', 'elections', 'includes', 'nonactive', 'Court', 'right', 'Unemployment', 'Standards', 'Commuting', 'Correctional', 'copyrightrelated', 'heritage', 'Separation', 'refers', 'attorney', 'Agriculture', 'Water', 'Language', 'Torts', 'revenues', 'relief', 'Endangered', 'Natural', 'Museums', 'claims', 'that', 'Samesex', 'Peoples', 'Womens', 'religious', 'bisexual', 'maplike', 'passengers', 'control', 'Valueadded', 'specifics', 'Common', 'Peace', 'funds', 'disabilities', 'Legislative', 'Pedestrians', 'punishment', 'it', 'preventive', 'trucking', 'collection', 'species', 'minorities', 'tracking', 'Veterans', 'Postal', 'specific', 'Aquaculture', 'Contracts', 'Electronic', 'sites', 'lands', 'legal', 'First', 'recreation', 'healthrelated', 'markets', 'violence', 'Driving', 'Equity', 'atlases', 'Tariffs', 'noncriminal', 'Encompasses', 'Mixed', 'royalties', 'spending', 'regions', 'organizations', 'proceedings', 'Associations', 'Property', 'law', 'transportation', 'Air', 'international', 'scientific', 'Genocide', 'Visas', 'research', 'Broadcasting', 'International', 'Preexisting', 'NGOsNGOs', 'Consumer', 'HIVAIDS', 'Statues', 'prices', 'Preschool', 'responders', 'liability', 'Judicial', 'Cultural', 'Economics', 'Education', 'Homelessness', 'Lawyers', 'legislatures', 'informed', 'imprisonment', 'School', 'Poverty', 'Oil', 'language', 'Cemeteries', 'enforcement', 'Animals', 'refuges', 'Coal', 'film', 'beverages', 'Freedom', 'rela ...

# %%
filter_words = list(unique_words - unique_function_words)
print(len(filter_words), filter_words)
# Out:
# 883 ['Infectious', 'passenger', 'service', 'Terrorism', 'Double', 'Gifted', 'Sector', 'parttime', 'Forfeiture', 'Income', 'Strategic', 'diet', 'fishing', 'commercial', 'Bridges', 'parks', 'Armed', 'products', 'review', 'industry', 'identify', 'guarantees', 'Labormanagement', 'Use', 'Maps', 'Childrens', 'stabilization', 'community', 'Recreation', 'Bicycling', 'jurisdictions', 'Floods', 'animals', 'Maintenance', 'loan', 'conditions', 'investment', 'Minority', 'Power', 'Libraries', 'prevention', 'Term', 'Refugees', 'News', 'Patients', 'Terminal', 'Juries', 'Territories', 'Trials', 'Nuclear', 'Weather', 'Guard', 'vehicles', 'organisms', 'Service', 'inheritance', 'Inheritance', 'Gambling', 'Blasphemy', 'crimes', 'Epidemics', 'participation', 'income', 'parties', 'cybercurrency', 'Disasters', 'Resources', 'DRAFT', 'biotechnology', 'information', 'restrictions', 'registers', 'Research', 'laws', 'Erosion', 'Animal', 'charitable', 'poaching', 'capital', 'Witnesses', 'buses', 'transmitted', 'Employment', 'immigrants', 'emergency', 'Segways', 'Charter', 'nuclear', 'documents', 'Environmental', 'cards', 'Rights', 'Taxation', 'Immigration', 'outpatient', 'Examples', 'Investment', 'boats', 'communications', 'groups', 'paramilitary', 'Corporations', 'Housing', 'Migrant', 'disobedience', 'Monetary', 'schools', 'Sentencing', 'Bankruptcy', 'treaty', 'conservation', 'Army', 'Tobacco', 'treaties', 'Crime', 'mitigation', 'GMO', 'Licensing', 'reform', 'terms', 'timber', 'relations', 'Roads', 'Genetically', 'property', 'Weapons', 'birth', 'consular', 'advertising', 'Credit', 'crises', 'Familybased', 'venue', 'debt', 'Force', 'planning', 'Securities', 'security', 'Navigation', 'Probation', 'institutions', 'Coast', 'US', 'media', 'navigation', 'resources', 'Hazardous', 'training', 'storm', 'Arts', 'Refers', 'areas', 'Pregnancy', 'Detention', 'Pornography', 'transgender', 'servitude', 'Hague', 'used', 'NATO', 'retirement', 'Small', 'costs', 'regulatory', 'Hunting', 'HIPAA', 'Desertification', 'Commerce', 'safety', 'Fraud', 'Budget', 'applied', 'Assault', 'Child', 'antitrust', 'Energy', 'Native', 'Customs', 'consent', 'custody', 'Transportation', 'pensions', 'modified', 'Soil', 'monuments', 'Foreign', 'defects', 'Infrastructure', 'Enforcement', 'speech', 'Plants', 'tax', 'pollution', 'Money', 'state', 'individuals', 'Technical', 'issues', 'Conservation', 'Archives', 'Disaster', 'contracts', 'political', 'health', 'insurance', 'lending', 'Cybersecurity', 'lesbian', 'utility', 'Census', 'assembly', 'Trademarks', 'elections', 'includes', 'nonactive', 'Court', 'right', 'Unemployment', 'Standards', 'Commuting', 'Correctional', 'copyrightrelated', 'heritage', 'Separation', 'refers', 'attorney', 'Agriculture', 'Water', 'Language', 'Torts', 'revenues', 'relief', 'Endangered', 'Natural', 'Museums', 'claims', 'Samesex', 'Peoples', 'Womens', 'religious', 'bisexual', 'maplike', 'passengers', 'control', 'Valueadded', 'specifics', 'Common', 'Peace', 'funds', 'disabilities', 'Legislative', 'Pedestrians', 'punishment', 'preventive', 'trucking', 'collection', 'species', 'minorities', 'tracking', 'Veterans', 'Postal', 'specific', 'Aquaculture', 'Contracts', 'Electronic', 'sites', 'lands', 'legal', 'First', 'recreation', 'healthrelated', 'markets', 'violence', 'Driving', 'Equity', 'atlases', 'Tariffs', 'noncriminal', 'Encompasses', 'Mixed', 'royalties', 'spending', 'regions', 'organizations', 'proceedings', 'Associations', 'Property', 'law', 'transportation', 'Air', 'international', 'scientific', 'Genocide', 'Visas', 'research', 'Broadcasting', 'International', 'Preexisting', 'NGOsNGOs', 'Consumer', 'HIVAIDS', 'Statues', 'prices', 'Preschool', 'responders', 'liability', 'Judicial', 'Cultural', 'Economics', 'Education', 'Homelessness', 'Lawyers', 'legislatures', 'informed', 'imprisonment', 'School', 'Poverty', 'Oil', 'language', 'Cemeteries', 'enforcement', 'Animals', 'refuges', 'Coal', 'film', 'beverages', 'Freedom', 'relates', 'dispute', 'Arctic', 'trust', 'care', 'loans ...

# %%
def count_words_on_webpages_and_translate(urls, unique_words):
    website_word_frequencies = {}
    translator = translate.Client()

    for url in urls:
        try:
            response = requests.get(url)
            if response.status_code == 200:
                soup = BeautifulSoup(response.text, 'html.parser')
                text = soup.get_text().lower()

                # Translate the text from Spanish to English
                translated_text = translator.translate(text, target_language='en')['translatedText'].lower()
                # Clean the text
                clean_text = re.sub('[^a-z\s]', '', translated_text)
                word_counts = Counter(clean_text.split())
                print(word_counts)

                if url not in website_word_frequencies:
                    website_word_frequencies[url] = {}
                
                print(word_counts.items())
                
                word_frequencies = {word: count for word, count in word_counts.items() if word in unique_words}
                print(word_frequencies)
                website_word_frequencies[url] = word_frequencies
                print(word_frequencies.items())
                # all_word_frequencies
            else:
                print(f"Skipping URL due to non-200 status code: {url}, status code: {response.status_code}")
                website_word_frequencies[url] = response.status_code
        except requests.RequestException as e:
            print(f"Skipping URL due to request exception: {url}, exception: {e}")
    # print(website_word_frequencies)

    # Convert the list to a DataFrame and write to an Excel file
    df = pd.DataFrame(website_word_frequencies)
    df = df.T
    df.to_excel('word_frequencies_test.xlsx', index=False)

# Example usage:
urls = ['https://boe.es/boe/dias/2005/12/30/']
count_words_on_webpages_and_translate(urls, filter_words)
# Out:
# Counter({'of': 815, 'the': 702, 'and': 218, 'pdf': 187, 'kb': 186, 'other': 180, 'for': 177, 'formats': 173, 'page': 123, 'resolution': 123, 'boeb': 108, 'by': 99, 'which': 95, 'december': 89, 'boea': 77, 'to': 71, 'public': 63, 'pages': 63, 'ministry': 61, 'in': 57, 'is': 57, 'a': 54, 'community': 45, 'general': 37, 'award': 36, 'council': 35, 'autonomous': 33, 'file': 32, 'agreement': 30, 'state': 27, 'de': 25, 'on': 24, 'service': 22, 'city': 22, 'open': 22, 'contracting': 21, 'made': 20, 'regarding': 20, 'between': 20, 'project': 20, 'announcing': 20, 'tender': 20, 'announcement': 20, 'university': 19, 'research': 19, 'social': 18, 'order': 17, 'directorate': 17, 'call': 17, 'competition': 17, 'institute': 17, 'air': 17, 'works': 16, 'procedure': 16, 'provide': 16, 'services': 15, 'supply': 15, 'collaboration': 15, 'support': 15, 'maintenance': 14, 'administration': 13, 'justice': 13, 'catalonia': 13, 'madrid': 13, 'with': 13, 'as': 13, 'management': 13, 'command': 13, 'contract': 13, 'information': 12, 'logistical': 12, 'official': 11, 'body': 11, 'technical': 11, 'place': 11, 'from': 11, 'force': 11, 'acquisition': 11, 'through': 11, 'hospital': 11, 'tourism': 10, 'national': 10, 'higher': 10, 'publicized': 10, 'science': 9, 'year': 9, 'gas': 9, 'new': 9, 'la': 9, 'scientific': 9, 'law': 8, 'galicia': 8, 'industry': 8, 'commerce': 8, 'labor': 8, 'affairs': 8, 'policy': 8, 'royal': 8, 'cleaning': 8, 'upload': 8, 'november': 8, 'barcelona': 8, 'secretary': 8, 'spanish': 8, 'secretariat': 8, 'study': 8, 'execution': 8, 'number': 8, 'facilities': 8, 'boe': 7, 'at': 7, 'asturias': 7, 'courts': 7, 'economy': 7, 'universities': 7, 'rights': 7, 'energy': 7, 'health': 7, 'decree': 7, 'control': 7, 'system': 7, 'municipal': 7, 'cdiz': 7, 'various': 7, 'people': 7, 'economic': 7, 'construction': 7, 'center': 7, 'company': 7, 'san': 7, 'department': 7, 'building': 7, 'title': 7, 'called': 7, 'fuenlabrada': 7, 'are': 6, 'provisions': 6, 'ii': 6, 'principality': 6, 'finance': 6, 'development': 6, 'environment': 6, 'eha': 6, 'mines': 6, 'transport': 6, 'valencian': 6, 'implementation': 6, 'an': 6, 'awarded': 6, 'sports': 6, 'publication': 6, 'dated': 6, 'assistance': 6, 'installation': 6, 'water': 6, 'infrastructure': 6, 'highway': 6, 'day': 5, 'no': 5, 'local': 5, 'andalusia': 5, 'defense': 5, 'education': 5, 'presidency': 5, 'program': 5, 'centers': 5, 'be': 5, 'several': 5, 'places': 5, 'urban': 5, 'lotteries': 5, 'bets': 5, 'out': 5, 'care': 5, 'residential': 5, 'expansion': 5, 'sa': 5, 'areas': 5, 'corresponding': 5, 'advertisements': 5, 'contracts': 5, 'aena': 5, 'airports': 5, 'navigation': 5, 'environmental': 5, 'provincial': 5, 'comprehensive': 5, 'malaga': 5, 'request': 5, 'section': 5, 'limited': 5, 'agency': 4, 'access': 4, 'legal': 4, 'appointments': 4, 'b': 4, 'v': 4, 'ads': 4, 'private': 4, 'bank': 4, 'cantabria': 4, 'castilelamancha': 4, 'into': 4, 'itc': 4, 'establishes': 4, 'natural': 4, 'prices': 4, 'registries': 4, 'notaries': 4, 'notary': 4, 'treasury': 4, 'convened': 4, 'real': 4, 'planning': 4, 'calls': 4, 'reform': 4, 'military': 4, 'provides': 4, 'territorial': 4, 'lottery': 4, 'result': 4, 'canary': 4, 'islands': 4, 'marine': 4, 'activity': 4, 'eci': 4, 'innovation': 4, 'published': 4, 'generality': 4, 'approving': 4, 'brand': 4, 'xd': 4, 'board': 4, 'work': 4, 'its': 4, 'sciences': 4, 'palma': 4, 'making': 4, 'spare': 4, 'parts': 4, 'different': 4, 'c': 4, 'equipment': 4, 'airport': 4, 'destined': 4, 'calling': 4, 'province': 4, 'assets': 4, 'administrative': 4, 'entity': 4, 'collado': 4, 'villalba': 4, 'street': 4, 'well': 4, 'santa': 4, 'cruz': 4, 'tenerife': 4, 'business': 4, 'preparation': 4, 'minutes': 4, 'prior': 4, 'occupation': 4, 'affected': 4, 'summary': 3, 'bulletin': 3, 'all': 3, 'judicial': 3, 'i': 3, 'authorities': 3, 'personnel': 3, 'situations': 3, 'competitions': 3, 'spain': 3, 'len': 3, 'judiciary': 3, 'commercial': 3, 'first': 3, 'administrations': 3, 'agriculture': 3, 'fisheries': 3, 'food ...
# dict_items([('boees', 1), ('summary', 3), ('of', 815), ('the', 702), ('day', 5), ('state', 27), ('agency', 4), ('official', 11), ('bulletin', 3), ('go', 1), ('to', 71), ('content', 1), ('consult', 1), ('gazette', 1), ('boe', 7), ('you', 2), ('can', 1), ('select', 1), ('another', 1), ('language', 1), ('castellanoes', 1), ('escastellano', 1), ('cacatal', 1), ('glgalego', 1), ('eueuskara', 1), ('vavalenci', 1), ('enenglish', 1), ('frfranais', 1), ('search', 1), ('for', 177), ('my', 2), ('disconnectedpress', 1), ('access', 4), ('service', 22), ('menu', 2), ('newspapers', 2), ('borme', 1), ('other', 180), ('legal', 4), ('information', 12), ('all', 3), ('law', 8), ('digital', 2), ('library', 2), ('services', 15), ('notifications', 1), ('judicial', 3), ('edicts', 1), ('auction', 2), ('portal', 1), ('advertisers', 1), ('are', 6), ('at', 7), ('home', 1), ('calendar', 1), ('previous', 1), ('next', 2), ('friday', 1), ('december', 89), ('no', 5), ('boes', 1), ('pdf', 187), ('xml', 1), ('sections', 1), ('i', 3), ('general', 37), ('provisions', 6), ('ii', 6), ('authorities', 3), ('and', 218), ('personnel', 3), ('appointments', 4), ('situations', 3), ('incidents', 2), ('b', 4), ('oppositions', 2), ('competitions', 3), ('iii', 2), ('iv', 2), ('administration', 13), ('justice', 13), ('v', 4), ('ads', 4), ('va', 1), ('auctions', 2), ('tenders', 1), ('works', 16), ('vb', 1), ('vc', 1), ('private', 4), ('departments', 2), ('local', 5), ('bank', 4), ('spain', 3), ('autonomous', 33), ('community', 45), ('andalusia', 5), ('cantabria', 4), ('castilelamancha', 4), ('catalonia', 13), ('galicia', 8), ('principality', 6), ('asturias', 7), ('castilla', 1), ('y', 1), ('len', 3), ('madrid', 13), ('council', 35), ('judiciary', 3), ('head', 2), ('commercial', 3), ('courts', 7), ('social', 18), ('first', 3), ('instance', 2), ('instruction', 2), ('ministry', 61), ('public', 63), ('administrations', 3), ('agriculture', 3), ('fisheries', 3), ('food', 3), ('culture', 2), ('defense', 5), ('economy', 7), ('finance', 6), ('education', 5), ('science', 9), ('development', 6), ('industry', 8), ('tourism', 10), ('commerce', 8), ('presidency', 5), ('environment', 6), ('labor', 8), ('affairs', 8), ('requirements', 3), ('universities', 7), ('advertising', 3), ('institutional', 3), ('communication', 3), ('on', 24), ('boea', 77), ('pages', 63), ('kb', 186), ('formats', 173), ('budgets', 2), ('year', 9), ('supplement', 1), ('metallic', 1), ('currency', 2), ('order', 17), ('eha', 6), ('by', 99), ('which', 95), ('modifies', 2), ('october', 3), ('agrees', 2), ('issuance', 1), ('minting', 1), ('putting', 1), ('into', 4), ('circulation', 1), ('collector', 2), ('coins', 1), ('quotfifa', 1), ('world', 1), ('cup', 1), ('germany', 1), ('quot', 2), ('page', 123), ('organization', 2), ('resolution', 123), ('tax', 2), ('attribution', 1), ('powers', 1), ('in', 57), ('area', 3), ('collection', 1), ('gas', 9), ('trade', 1), ('regulated', 2), ('activities', 2), ('itc', 4), ('establishes', 4), ('remuneration', 1), ('sector', 2), ('installations', 2), ('tolls', 1), ('fees', 1), ('associated', 1), ('with', 13), ('third', 1), ('party', 1), ('rates', 2), ('natural', 4), ('manufactured', 2), ('gases', 2), ('pipeline', 2), ('rental', 1), ('meters', 1), ('connection', 3), ('rights', 7), ('consumers', 1), ('connected', 1), ('networks', 1), ('a', 54), ('supply', 15), ('pressure', 1), ('equal', 2), ('or', 3), ('less', 1), ('than', 2), ('bar', 1), ('petroleum', 2), ('products', 1), ('prices', 4), ('directorate', 17), ('energy', 7), ('policy', 8), ('mines', 6), ('new', 9), ('maximum', 2), ('sales', 2), ('before', 1), ('taxes', 1), ('packaged', 1), ('liquefied', 1), ('made', 20), ('containers', 2), ('greater', 2), ('capacity', 1), ('kg', 1), ('use', 1), ('as', 13), ('raw', 1), ('material', 2), ('plant', 2), ('health', 7), ('royal', 8), ('decree', 7), ('july', 2), ('national', 10), ('program', 5), ('eradication', 1), ('control', 7), ('fire', 3), ('blight', 1), ('rosaceae', 1), ('vocational', 1), ('training' ...
# {'state': 27, 'language': 1, 'service': 22, 'other': 180, 'legal': 4, 'information': 12, 'law': 8, 'services': 15, 'general': 37, 'personnel': 3, 'administration': 13, 'works': 16, 'private': 4, 'local': 5, 'community': 45, 'commercial': 3, 'courts': 7, 'public': 63, 'fisheries': 3, 'finance': 6, 'education': 5, 'development': 6, 'industry': 8, 'labor': 8, 'advertising': 3, 'order': 17, 'resolution': 123, 'tax': 2, 'powers': 1, 'collection': 1, 'gas': 9, 'trade': 1, 'activities': 2, 'fees': 1, 'rates': 2, 'natural': 4, 'rights': 7, 'products': 1, 'prices': 4, 'policy': 8, 'mines': 6, 'sales': 2, 'use': 1, 'plant': 2, 'health': 7, 'national': 10, 'control': 7, 'training': 3, 'conditions': 2, 'vehicles': 2, 'scope': 2, 'court': 2, 'procedure': 16, 'system': 7, 'organizations': 2, 'technology': 2, 'property': 2, 'civil': 3, 'management': 13, 'planning': 4, 'bodies': 2, 'reform': 4, 'military': 4, 'covered': 1, 'research': 19, 'scientific': 9, 'fishing': 1, 'quality': 2, 'actions': 1, 'innovation': 4, 'subsidies': 1, 'credits': 1, 'construction': 7, 'care': 5, 'support': 15, 'disabilities': 2, 'agencies': 1, 'telecommunications': 2, 'plans': 2, 'government': 3, 'work': 4, 'areas': 5, 'aid': 1, 'women': 1, 'forces': 2, 'status': 1, 'exchange': 2, 'political': 1, 'matters': 3, 'air': 17, 'weapons': 2, 'systems': 3, 'materials': 2, 'transportation': 2, 'contracts': 5, 'transfer': 2, 'medical': 2, 'airports': 5, 'navigation': 5, 'assistance': 6, 'surveillance': 1, 'employees': 1, 'facilities': 8, 'called': 7, 'water': 6, 'security': 3, 'canals': 1, 'treatment': 1, 'buildings': 3, 'resources': 1, 'conservation': 2, 'devices': 1, 'hiring': 1, 'waste': 1, 'schools': 1, 'safety': 3, 'succession': 1, 'transmission': 1, 'business': 4, 'occupation': 4, 'section': 5, 'terms': 1, 'international': 2, 'highways': 1, 'markets': 1, 'specific': 1, 'financial': 1, 'loan': 1, 'proceedings': 1, 'utility': 3, 'protection': 1}
# dict_items([('state', 27), ('language', 1), ('service', 22), ('other', 180), ('legal', 4), ('information', 12), ('law', 8), ('services', 15), ('general', 37), ('personnel', 3), ('administration', 13), ('works', 16), ('private', 4), ('local', 5), ('community', 45), ('commercial', 3), ('courts', 7), ('public', 63), ('fisheries', 3), ('finance', 6), ('education', 5), ('development', 6), ('industry', 8), ('labor', 8), ('advertising', 3), ('order', 17), ('resolution', 123), ('tax', 2), ('powers', 1), ('collection', 1), ('gas', 9), ('trade', 1), ('activities', 2), ('fees', 1), ('rates', 2), ('natural', 4), ('rights', 7), ('products', 1), ('prices', 4), ('policy', 8), ('mines', 6), ('sales', 2), ('use', 1), ('plant', 2), ('health', 7), ('national', 10), ('control', 7), ('training', 3), ('conditions', 2), ('vehicles', 2), ('scope', 2), ('court', 2), ('procedure', 16), ('system', 7), ('organizations', 2), ('technology', 2), ('property', 2), ('civil', 3), ('management', 13), ('planning', 4), ('bodies', 2), ('reform', 4), ('military', 4), ('covered', 1), ('research', 19), ('scientific', 9), ('fishing', 1), ('quality', 2), ('actions', 1), ('innovation', 4), ('subsidies', 1), ('credits', 1), ('construction', 7), ('care', 5), ('support', 15), ('disabilities', 2), ('agencies', 1), ('telecommunications', 2), ('plans', 2), ('government', 3), ('work', 4), ('areas', 5), ('aid', 1), ('women', 1), ('forces', 2), ('status', 1), ('exchange', 2), ('political', 1), ('matters', 3), ('air', 17), ('weapons', 2), ('systems', 3), ('materials', 2), ('transportation', 2), ('contracts', 5), ('transfer', 2), ('medical', 2), ('airports', 5), ('navigation', 5), ('assistance', 6), ('surveillance', 1), ('employees', 1), ('facilities', 8), ('called', 7), ('water', 6), ('security', 3), ('canals', 1), ('treatment', 1), ('buildings', 3), ('resources', 1), ('conservation', 2), ('devices', 1), ('hiring', 1), ('waste', 1), ('schools', 1), ('safety', 3), ('succession', 1), ('transmission', 1), ('business', 4), ('occupation', 4), ('section', 5), ('terms', 1), ('international', 2), ('highways', 1), ('markets', 1), ('specific', 1), ('financial', 1), ('loan', 1), ('proceedings', 1), ('utility', 3), ('protection', 1)])

# %%
import pandas as pd

# Example data
data = {
    "http://example.com": {"apple": 4, "banana": 2, "cherry": 1},
    "http://another.com": {"banana": 5, "date": 3},
    "http://site.com": {"apple": 1, "cherry": 2, "date": 2, "fig": 1},
}

# Prepare data for DataFrame
rows = []
for url, words in data.items():
    for word, count in words.items():
        rows.append((url, word, count))

# Create DataFrame
df = pd.DataFrame(rows, columns=["URL", "Word", "Count"])

# Export to Excel
with pd.ExcelWriter('output_with_merged_cells.xlsx', engine='xlsxwriter') as writer:
    df.to_excel(writer, index=False, sheet_name='Sheet1', columns=["URL", "Word", "Count"])

    workbook = writer.book
    worksheet = writer.sheets['Sheet1']

    # Add the URL in the first column and merge as needed
    url_row_map = {}
    for i, (url, _) in enumerate(df.groupby('URL')):
        start_row = i * len(_) + 1  # +1 to account for header row
        end_row = start_row + len(_) - 1
        url_row_map[url] = (start_row, end_row)

        # Merge cells for the URL
        worksheet.merge_range(start_row, 0, end_row, 0, url)

    # Optionally adjust the column widths
    worksheet.set_column('A:A', 20)
    worksheet.set_column('B:B', 15)
    worksheet.set_column('C:C', 10)

# %%
import random
import string

def generate_word():
    """Generate a random word using lowercase letters."""
    return ''.join(random.choice(string.ascii_lowercase) for _ in range(random.randint(4, 10)))

def create_test_data(num_urls=5, words_per_url=120, error_url_index=2, error_message="HTTP Error 404: Not Found"):
    """Create a dictionary with specified number of URLs, each with a given number of unique words.
       One URL will be designated to return an error message instead of a word list.
    """
    data = {}
    for i in range(num_urls):
        url = f"http://example{i+1}.com"
        if i == error_url_index:
            # Assign an error message to this URL instead of word list
            data[url] = error_message
        else:
            words = {generate_word() for _ in range(words_per_url)}
            data[url] = list(words)
    return data

# Generate test data with one error URL
test_data = create_test_data()

# Display some of the data to verify
for url, content in test_data.items():
    print(f'{url}, {content}')
# Out:
# http://example1.com, ['edomlo', 'ttlspoyb', 'vbdbozut', 'hthnorjym', 'qlurl', 'sebpn', 'ygjwmeyq', 'avyfgn', 'ohsyq', 'upab', 'wdgiiu', 'yggzvw', 'ftrgyla', 'hfkc', 'zbelx', 'wcbtrpdw', 'fzlg', 'qoqccyybjw', 'mzcvmrnvr', 'nxukt', 'abuiilazlr', 'gogkkg', 'ofsjw', 'slibde', 'gukeud', 'odqerkxv', 'kzojynthvc', 'rdmudnqbky', 'tpetum', 'elqxiu', 'otzapojnu', 'slktaxo', 'vzpdhdv', 'rfbyvajo', 'ogzw', 'qkswyn', 'uzhybsfu', 'hfcnzgs', 'mvtqqy', 'bgrdiu', 'vjeorlw', 'oivqcoa', 'kzvnwb', 'covmnaeuya', 'ccrdtsi', 'egib', 'kowcjhu', 'qgvk', 'nfkbesbs', 'cpoqayuns', 'kqxxejpw', 'vhbukel', 'adptndpoud', 'vkhaq', 'kfijuck', 'htfgmkpe', 'lwlpopezq', 'yrphzpzhp', 'jinncytlmt', 'mtasaecb', 'kazsvbfl', 'jooclm', 'vkyxkcvrb', 'mhfxbjwyy', 'svqepbl', 'rzptl', 'wvrgtjbkz', 'patnomsnz', 'jwucrg', 'oszcy', 'fixvu', 'rank', 'cjsjdre', 'ouudx', 'stqoaozu', 'ilzhz', 'bxpjijn', 'dwgjurr', 'tatzgdmj', 'ovndwq', 'qtqpceaoq', 'lshcnykgt', 'gxdqcdwhw', 'ogkwcykbqx', 'bmmyr', 'koqgmx', 'cbelyt', 'albwpeel', 'qdly', 'bzvgiivwpv', 'qsgn', 'jtjvtdehfr', 'khrzkkqf', 'mjqdvkv', 'ztvzxbww', 'ngyrutv', 'gknllkyk', 'criszsekv', 'mdiot', 'ecsdjwcnrb', 'bquj', 'ajdxqql', 'ibpf', 'bhmpwypajn', 'tuve', 'rujvulqcw', 'mkzwd', 'avlubmfz', 'ymdpyxqfyd', 'siva', 'zmhpfbecrd', 'xeobjljft', 'bcnrsmipa', 'qmaduk', 'jdgfnntuw', 'zhpctr', 'aoqh', 'uxrtlvhdp', 'oueszt', 'tajjuef']
# http://example2.com, ['avlllft', 'otmlvmuwav', 'pqsjibe', 'idwlthh', 'iidi', 'tgmwkk', 'sqqaqxa', 'xubhqjqpyb', 'gcrvys', 'oogtdksw', 'rltroyzs', 'pfidol', 'dzbzyavg', 'ezcdgp', 'zprsnmwua', 'tfozrzv', 'czrlembku', 'dssntlmmp', 'wnctkpvbbr', 'mlnu', 'eejcuhkvl', 'fowkuf', 'znkkhi', 'nahrkshmr', 'bxpdfi', 'abdbhudfo', 'plkuooeo', 'clht', 'kkrluzyqkd', 'ritt', 'yredlzlnzm', 'qmumrthspt', 'zawt', 'azczzlru', 'ddkyecnzlx', 'ynojyi', 'gpwhnp', 'xwauf', 'idgd', 'setigb', 'feej', 'fsbqk', 'pxjcwb', 'mwehyl', 'brlodbjdz', 'zvvgmi', 'ngiej', 'bawsos', 'aqiviurxqx', 'zbxhpzvajq', 'ytao', 'obtjmrq', 'lwxgwhqu', 'rdxfobnpyy', 'hdntyiak', 'vodfbpano', 'amyqay', 'piawn', 'oqutznt', 'vjxxdklm', 'slwbmxswe', 'gxdzkf', 'rnzbkih', 'irccxntpgi', 'yezrs', 'cvgonvm', 'ajpdwtcy', 'qekxhwwtkx', 'gkdshk', 'nkkubkc', 'kyivn', 'odhfhgw', 'pedcsy', 'ioozbtuesv', 'ggep', 'nvpinevxlb', 'dxmkdsojvp', 'qgvtpugcad', 'bitlkjg', 'friuqp', 'vwpdbtqcyu', 'bjahoqq', 'xfueqoddnw', 'cvpgdmlgll', 'ehgatdbth', 'rpyg', 'fatilz', 'aiwokh', 'hpfiff', 'yflps', 'moljvopxj', 'vgnrww', 'ymwt', 'tutfui', 'zpbmhfxv', 'ssdflfeu', 'fivcubcv', 'ktnkcwp', 'lxpoqdyps', 'qhjjqxrut', 'ckxrqqbl', 'rtuqpz', 'lwpnndpbdx', 'jcfavqpi', 'jiikuwfox', 'nbhimnvy', 'knvpiqnso', 'kklzgew', 'rtdewsxvbu', 'liua', 'vyvjzwpyj', 'kywr', 'horztawnkw', 'dscqmke', 'jfwtztzl', 'fwuklfgzq', 'kanzjqzqa', 'lgll', 'kjlimotxa', 'xnvbcfrz']
# http://example3.com, HTTP Error 404: Not Found
# http://example4.com, ['lpebezn', 'owqynffh', 'bchnr', 'yxvg', 'tyobblgile', 'wnceg', 'rnedfiaex', 'isifsmxcg', 'kqaw', 'rztlc', 'fourp', 'jydmdhwtzu', 'ujarqgdw', 'ysynosmowl', 'abzkfs', 'oibfretoa', 'vlblpom', 'czhttzddeh', 'tzzid', 'urtktwk', 'ytqgr', 'vzavjb', 'fpuvl', 'hnfsl', 'yvuccxoeon', 'gyazzxvn', 'hzynvyppa', 'lyaed', 'gzhyv', 'dfpbu', 'jdzw', 'lorwm', 'oxvtpkc', 'lhmg', 'zpmvpwrtpx', 'acztakkdk', 'uohlchf', 'jemsp', 'huomzxa', 'hfivmtod', 'inzvk', 'elquqekpsp', 'duyqwrz', 'elkswm', 'tyrhg', 'kkhxyijtgp', 'hmkbftm', 'rgztpkqzd', 'xxshqozloi', 'splbuh', 'jyklpdzj', 'scgjw', 'attnb', 'shgob', 'ciumjylnxx', 'fnayjwz', 'wrowj', 'xdcsvoovhd', 'wgptn', 'nqmsrbsf', 'nrkyllxbl', 'hcbjqa', 'hxnt', 'gagl', 'ibyp', 'tfinpv', 'qgvjxmjxgl', 'qgalglxodg', 'vvltajlatq', 'sqryrerxio', 'agegkd', 'akfjib', 'yopwcxcnh', 'wnwvmfne', 'yddx', 'fnxii', 'pwxzgropim', 'vfsojz', 'raupi', 'zlxde', 'nujk', 'tgxvzsly', 'fqkleyq', 'lpjfd', 'byymee', 'ouctgbi', 'wfqguy', 'xasxnq', 'thvf', 'sviftuein', 'cxfvez', 'uocispheg', 'qezgf', 'tkkzxuqcad', 'znnwt', 'tdvx', 'lcnunscgao', 'tifyzdgrk', 'pzlmytri', 'lzyubmvd', 'hqkohvl', 'aqgq', 'bmugyg', 'vyjps', 'zbtsevlme', 'nfxfu', 'cxlmeq', 'dggnivznyl', 'oiqyth', 'mofuscm', 'tgxvsprezt', 'jmuknbysq', 'qdkiz', 'xixov', 'oeyqyuwotr', 'cjcyf', 'upyxjqits', 'nnnqg', 'ncnmuxoqx', 'qvbejfn']
# http://example5.com, ['gltinjjk', 'cgcgfhzfqj', 'tgdkjrhs', 'rvsoyspcxq', 'wqoxa', 'gankbi', 'xnilb', 'wqpm', 'sefxpu', 'okuadof', 'asvsuair', 'awjmrf', 'iwgodp', 'hgpiyquum', 'fnynusgu', 'czouvs', 'fzhcbmei', 'kexaydmfv', 'ulemjyq', 'jbnq', 'edscleld', 'gjkas', 'cumg', 'owdzbnzctr', 'qjrvfrylt', 'xrfp', 'rwfmdmm', 'rgvvywg', 'tbrni', 'hqwjsy', 'podyi', 'hzeftuotug', 'ocpq', 'oyjzwtj', 'znwrc', 'ollh', 'xxsnbrs', 'gdebluul', 'nsrhqyb', 'uvfwydheqc', 'insv', 'xjhn', 'hzjiwz', 'ontkyw', 'xjecsczb', 'vahedzeujg', 'meazykzwo', 'fkpbdlnz', 'szqgmecbrv', 'peyjnm', 'ayychjkcxw', 'ihgtzqdfh', 'qlscgyyx', 'zoylusuo', 'kzdljt', 'qsehyn', 'hbfbs', 'rcykuo', 'qudkq', 'jqeizfl', 'vtmqm', 'foas', 'mhvyzpxmz', 'awmdrhyy', 'swqg', 'bwjllioqii', 'qboccbbu', 'uckhprcvj', 'bbsqzuft', 'zgeciznfjd', 'npqk', 'taawa', 'scpv', 'xuoskbax', 'uvhlcp', 'xgfxfnm', 'ughs', 'axayczl', 'cpgmbw', 'luyrrgu', 'zobzgex', 'cnljeyorqh', 'bklyyum', 'ekhtczki', 'xxty', 'bcnjxrungp', 'dhfraqxbq', 'iaiu', 'svlkw', 'sanigf', 'xcxm', 'hnpc', 'bqcvcrseqp', 'rvuajuugu', 'zmsuvwn', 'iqutpc', 'tvjzod', 'hufk', 'fbserserh', 'mpmb', 'ynhzm', 'cnqltta', 'kdpse', 'fkjm', 'wvcsn', 'qdbaa', 'qmjsp', 'obtdapgql', 'umoftl', 'fbcxy', 'wvykeuct', 'qxdxkig', 'hejeto', 'cbfse', 'gvcy', 'eydt', 'jmbxxpydp', 'sqjfddiv', 'zyibvnj', 'poeuqyj']

# %%
import pandas as pd

# Example data structure
data = {
    "http://example.com": ["apple", "banana", "cherry"],
    "http://another.com": "HTTP Error 404: Not Found",  # This URL returned an error
    "http://site.com": ["apple", "cherry", "date", "fig"],
}

# Parameters
max_cols = 20  # Maximum number of columns for words

# Function to prepare data for DataFrame
def prepare_data(data, max_cols):
    rows = []
    merge_info = []
    for url, content in data.items():
        if isinstance(content, list):  # Check if the content is a list of words
            num_rows = -(-len(content) // max_cols)  # Ceiling division for rows
            merge_info.append((url, num_rows))

            # Split words into the appropriate number of rows
            for start in range(0, len(content), max_cols):
                end = start + max_cols
                row = [url] + content[start:end]
                row += [None] * (max_cols - len(content[start:end]))  # Correct padding calculation
                rows.append(row)
        else:
            # Handle error messages
            row = [url] + [content] + [None] * (max_cols - 1)  # Correct number of None to fill up the row
            rows.append(row)
            merge_info.append((url, 1))  # Only one row for error messages

    return rows, merge_info

# Prepare rows and merging information
data_rows, merge_info = prepare_data(test_data, max_cols)

# Create DataFrame
column_names = ['URL'] + [f"Word_{i+1}" for i in range(max_cols)]
df = pd.DataFrame(data_rows, columns=column_names)

# Export to Excel with merged cells and formatted headers
with pd.ExcelWriter('output_with_merged_cells_MATRIX.xlsx', engine='xlsxwriter') as writer:
    df.to_excel(writer, index=False, sheet_name='Sheet1')
    workbook = writer.book
    worksheet = writer.sheets['Sheet1']

    # Formatting for headers and cells
    header_format = workbook.add_format({'bold': True, 'align': 'left', 'valign': 'top'})
    text_format = workbook.add_format({'bold': True, 'align': 'center', 'valign': 'vcenter', 'font_color': 'black'})

    # Merge the word headers into one cell and name it "Unique Words"
    worksheet.merge_range(0, 1, 0, max_cols, 'Unique Words', header_format)

    # Apply formatting to URLs to prevent Excel from auto-formatting as hyperlinks
    for index, _ in enumerate(data_rows):
        worksheet.write_string(index + 1, 0, data_rows[index][0], text_format)  # +1 for header row

    # Apply merging for URL column based on the number of rows each URL occupies
    current_row = 1  # Excel rows start from 1 and account for the header
    for url, rows in merge_info:
        # Only apply the merging if more than one row is needed for the URL
        if rows > 1:
            worksheet.merge_range(current_row, 0, current_row + rows - 1, 0, url, text_format)
        current_row += rows

    # Set column widths
    worksheet.set_column(0, 0, 20)  # URL column wider
    for i in range(max_cols):
        worksheet.set_column(i+1, i+1, 15)  # Word columns
